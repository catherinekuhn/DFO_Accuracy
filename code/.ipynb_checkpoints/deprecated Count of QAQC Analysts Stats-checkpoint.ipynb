# %%
# This notebook was built in Catherine's vectorenv
import pandas as pd
from pandas import DataFrame
import numpy as np
import os
import glob
import datetime
import pylab
import matplotlib as plt
import datetime as datetime  
import statsmodels.api as sm  
import matplotlib.pyplot as plt
import seaborn as sns

# plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
# %cd /Users/ckuhn/Downloads
df = pd.read_csv('QAQC_stats.csv', low_memory=False)
# Out:
# /Users/ckuhn/Downloads

# %%
df
# Out:
#       Flood Completed By       Group
# 0      1992       Albert  Scientists
# 1      1993       Albert  Scientists
# 2      1994       Albert  Scientists
# 3      1995       Albert  Scientists
# 4      1996       Albert  Scientists
# 5      1997       Albert  Scientists
# 6      1998       Albert  Scientists
# 7      1999       Albert  Scientists
# 8      2000       Albert  Scientists
# 9      2001       Albert  Scientists
# 10     2002       Albert  Scientists
# 11     2003       Albert  Scientists
# 12     2004       Albert  Scientists
# 13     2005       Albert  Scientists
# 14     2006       Albert  Scientists
# 15     2007       Albert  Scientists
# 16     2008       Albert  Scientists
# 17     2009       Albert  Scientists
# 18     2010       Albert  Scientists
# 19     2011       Albert  Scientists
# 20     2012       Albert  Scientists
# 21     2013       Albert  Scientists
# 22     2014       Albert  Scientists
# 23     2015       Albert  Scientists
# ...

# %%
df.columns
# Out:
# Index([u'Flood', u'Completed By', u'Group'], dtype='object')

# %%
def set_style():
    plt.style.use(['seaborn-white', 'seaborn-talk'])
    plt.rc("font", family="Times New Roman", size = 22)
    plt.rc('xtick', labelsize=22) 
    plt.rc('ytick', labelsize=22) 
set_style()  

fig.set_size_inches(10, 7.5)

df.groupby(['Completed By'])['Flood'].count().plot(kind='bar')

# %%
fig.set_size_inches(10, 7.5)

df.groupby(['Group'])['Flood'].count().plot(kind='bar')
